# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
# Dependencies
import numpy as np
import pandas as pd

# %%
# import sys
# print(sys.version)

# %%
# import tensorflow
# tensorflow.keras.__version__

# %%
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html#stellar_param
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %%
Xtemp = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec', 'koi_period','koi_time0bk','koi_slogg','koi_srad','koi_impact','koi_duration','koi_depth','koi_prad','koi_teq','koi_insol','koi_model_snr','koi_steff','koi_slogg','koi_srad','ra','dec','koi_kepmag']]
Xtemp
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_time0bk  koi_slogg  koi_srad  koi_impact  koi_duration  ...  \
# 0      162.513840      4.467     0.927       0.586       4.50700  ...
# 1      175.850252      4.544     0.868       0.969       1.78220  ...
# 2      170.307565      4.564     0.791       1.276       2.40641  ...
# 3      171.595550      4.438     1.046       0.701       1.65450  ...
# 4      172.979370      4.486     0.972       0.762       3.14020  ...
# ...           ...        ...       ...         ...           ...  ...
# 6986   132.016100      4.296     1.088       0.765       4.80600  ...
# 6987   131.705093      4.529     0.903       1.252       3.22210  ...
# 6988   133.001270      4.444     1.031       0.043       3.11400  ...
# 6989   132.181750      4.447     1.041       0.147       0.86500  ...
# 6990   135.993300      4.385     1.193       0.134       3.07800  ...
#
#       koi_prad  koi_teq  koi_insol  koi_model_snr  koi_steff  koi_slogg  \
# 0         2.83      443       9.11           25.8       5455      4.467
# 1        14.60      638      39.30           76.3       5853      4.544
# 2        33.46     1395     891.96          505.6       5805      4.564
# 3         2.75     1406     926.16           40.9       6031      4.438
# 4         2.77     1160     427.65           40.2       6046      4.486
# ...        ...      ...        ...            ...        ...        ...
# 6986      1.11      929     176.40            8.4       5638      4.296
# 6987     29.35     2088    4500.53          453.3       5638      4.529
# 6988      0.72     1608    1585.81           10.6       6119      4.444
# 6989      1.07     2218    5713.41           12.3       6173      4.447
# 6990      1.05     1266     607.42            8.2       6469      4.385
#
#       koi_srad         ra        dec  koi_kepmag
# 0        0.927  291.93423  48.141651      15.347
# 1        0.868  297.00482  48.134129      15.436
# 2        0.791  285.53461  48.285210      15.597
# 3        1.046  288.75488  48.226200      15.509
# 4        0.972  296.28613  48.224670      15.714
# ...        ...        ...        ...         ...
# 6986     1.088  298.74921  46.973351      14.478
# 6987     0.903  297.18875  47.093819      14.082
# 6988     1.031  286.50937  47.163219      14.757
# 6989     1.041  294.16489  47.176281      15.385
# 6990     1.193  297.00977  47.121021      14.826
#
# [6991 rows x 21 columns]

# %%
y = df[['koi_disposition']]

# %%
# data_binary_encoded = pd.get_dummies(y, columns=["koi_disposition"])
# data_binary_encoded.columns = [["candidate","confirmed","false_positive"]]

# %%
# from sklearn.ensemble import RandomForestClassifier
# rf = RandomForestClassifier(n_estimators=200)
# rf = rf.fit(Xtemp, data_binary_encoded)

# %%
# # Random Forests in sklearn will automatically calculate feature importance
# importances = rf.feature_importances_
# importances

# %%
# # We can sort the features by their importance
# sorted(zip(rf.feature_importances_, Xtemp), reverse=True)

# %% [markdown]
# #### based on past history directly removing insignificant features based on feature_importance

# %%
X = Xtemp.drop(columns=['ra','dec','koi_kepmag','koi_srad','koi_slogg'])
X
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 0      162.513840       0.586       4.50700      874.8      2.83      443
# 1      175.850252       0.969       1.78220    10829.0     14.60      638
# 2      170.307565       1.276       2.40641     8079.2     33.46     1395
# 3      171.595550       0.701       1.65450      603.3      2.75     1406
# 4      172.979370       0.762       3.14020      686.0      2.77     1160
# ...           ...         ...           ...        ...       ...      ...
# 6986   132.016100       0.765       4.80600       87.7      1.11      929
# 6987   131.705093       1.252       3.22210     1579.2     29.35     2088
# 6988   133.001270       0.043       3.11400       48.5      0.72     1608
# 6989   132.181750       0.147       0.86500      103.6      1.07     2218
# 6990   135.993300       0.134       3.07800       76.7      1.05     1266
#
#       koi_insol  koi_model_snr  koi_steff
# 0          9.11           25.8       5455
# 1         39.30           76.3       5853
# 2        891.96          505.6       5805
# 3        926.16           40.9       6031
# 4        427.65           40.2       6046
# ...         ...            ...        ...
# 6986     176.40            8.4       5638
# 6987    4500.53          453.3       5638
# 6988    1585.81           10.6       6119
# 6989    5713.41           12.3       6173
# 6990     607.42            8.2       6469
#
# [6991 rows x 14 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = X.columns
selected_features
# Out:
# Index(['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co', 'koi_fpflag_ec',
#        'koi_period', 'koi_time0bk', 'koi_impact', 'koi_duration', 'koi_depth',
#        'koi_prad', 'koi_teq', 'koi_insol', 'koi_model_snr', 'koi_steff'],
#       dtype='object')

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(X.shape, y.shape)
# Out:
# (6991, 14) (6991, 1)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 6122   133.077240       0.150       3.61600      123.1      1.24     1017
# 6370   132.020050       0.291       2.30900      114.6      0.86     1867
# 2879   134.460380       0.970      79.89690      641.1      3.21      989
# 107    174.662240       0.300       2.63120      875.4      2.25      696
# 29     172.258529       0.831       2.22739     9802.0     12.21     1103
#
#       koi_insol  koi_model_snr  koi_steff
# 6122     253.30           10.8       5737
# 6370    2891.64           13.8       5855
# 2879     226.81          254.3       6328
# 107       55.37           38.4       4768
# 29       349.40          696.5       5712

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
print(X_train_scaled.shape, y_train_categorical.shape)
# Out:
# (5243, 14) (5243, 3)

# %% [markdown]
# # Train the Model

# %%
# create deep learning model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
# give no. of columns in y_train_categorical as input_dim
model.add(Dense(units=100, activation='relu', input_dim=14))
model.add(Dense(units=100, activation='relu'))
# give of columns in y_train_categorical as units
model.add(Dense(units=3, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               1500
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 11,903
# Trainable params: 11,903
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=15,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 5243 samples
# Epoch 1/15
# 5243/5243 - 1s - loss: 0.5409 - accuracy: 0.7044
# Epoch 2/15
# 5243/5243 - 0s - loss: 0.3787 - accuracy: 0.7833
# Epoch 3/15
# 5243/5243 - 0s - loss: 0.3708 - accuracy: 0.7910
# Epoch 4/15
# 5243/5243 - 0s - loss: 0.3657 - accuracy: 0.7978
# Epoch 5/15
# 5243/5243 - 0s - loss: 0.3618 - accuracy: 0.7940
# Epoch 6/15
# 5243/5243 - 0s - loss: 0.3589 - accuracy: 0.8039
# Epoch 7/15
# 5243/5243 - 0s - loss: 0.3557 - accuracy: 0.8051
# Epoch 8/15
# 5243/5243 - 0s - loss: 0.3530 - accuracy: 0.8070
# Epoch 9/15
# 5243/5243 - 0s - loss: 0.3503 - accuracy: 0.8135
# Epoch 10/15
# 5243/5243 - 0s - loss: 0.3494 - accuracy: 0.8114
# Epoch 11/15
# 5243/5243 - 0s - loss: 0.3467 - accuracy: 0.8148
# Epoch 12/15
# 5243/5243 - 0s - loss: 0.3440 - accuracy: 0.8177
# Epoch 13/15
# 5243/5243 - 0s - loss: 0.3415 - accuracy: 0.8150
# Epoch 14/15
# 5243/5243 - 0s - loss: 0.3388 - accuracy: 0.8230
# Epoch 15/15
# 5243/5243 - 0s - loss: 0.3365 - accuracy: 0.8230

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1748/1 - 0s - loss: 0.3523 - accuracy: 0.8026
# Deep Neural Network - Loss: 0.3657203559471759, Accuracy: 0.8026315569877625

# %%
# model.fit(
#     X_train_scaled,
#     y_train_categorical,
#     epochs=80,
#     shuffle=True,
#     verbose=2
# )

# %%
# model_loss, model_accuracy = model.evaluate(
#     X_test_scaled, y_test_categorical, verbose=2)
# print(
#     f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 5243 samples
# Epoch 1/100
# 5243/5243 - 0s - loss: 0.3362 - accuracy: 0.8230
# Epoch 2/100
# 5243/5243 - 0s - loss: 0.3304 - accuracy: 0.8270
# Epoch 3/100
# 5243/5243 - 0s - loss: 0.3293 - accuracy: 0.8282
# Epoch 4/100
# 5243/5243 - 0s - loss: 0.3250 - accuracy: 0.8325
# Epoch 5/100
# 5243/5243 - 0s - loss: 0.3202 - accuracy: 0.8390
# Epoch 6/100
# 5243/5243 - 0s - loss: 0.3201 - accuracy: 0.8369
# Epoch 7/100
# 5243/5243 - 0s - loss: 0.3187 - accuracy: 0.8371
# Epoch 8/100
# 5243/5243 - 0s - loss: 0.3163 - accuracy: 0.8411
# Epoch 9/100
# 5243/5243 - 0s - loss: 0.3118 - accuracy: 0.8436
# Epoch 10/100
# 5243/5243 - 0s - loss: 0.3094 - accuracy: 0.8484
# Epoch 11/100
# 5243/5243 - 0s - loss: 0.3060 - accuracy: 0.8457
# Epoch 12/100
# 5243/5243 - 0s - loss: 0.3062 - accuracy: 0.8461
# Epoch 13/100
# 5243/5243 - 0s - loss: 0.3013 - accuracy: 0.8554
# Epoch 14/100
# 5243/5243 - 0s - loss: 0.3034 - accuracy: 0.8482
# Epoch 15/100
# 5243/5243 - 0s - loss: 0.2984 - accuracy: 0.8602
# Epoch 16/100
# 5243/5243 - 0s - loss: 0.2951 - accuracy: 0.8632
# Epoch 17/100
# 5243/5243 - 0s - loss: 0.2934 - accuracy: 0.8625
# Epoch 18/100
# 5243/5243 - 0s - loss: 0.2976 - accuracy: 0.8577
# Epoch 19/100
# 5243/5243 - 0s - loss: 0.2910 - accuracy: 0.8592
# Epoch 20/100
# 5243/5243 - 0s - loss: 0.2888 - accuracy: 0.8661
# Epoch 21/100
# 5243/5243 - 0s - loss: 0.2865 - accuracy: 0.8682
# Epoch 22/100
# 5243/5243 - 0s - loss: 0.2856 - accuracy: 0.8661
# Epoch 23/100
# 5243/5243 - 0s - loss: 0.2808 - accuracy: 0.8747
# Epoch 24/100
# 5243/5243 - 0s - loss: 0.2812 - accuracy: 0.8760
# Epoch 25/100
# 5243/5243 - 0s - loss: 0.2797 - accuracy: 0.8714
# Epoch 26/100
# 5243/5243 - 0s - loss: 0.2786 - accuracy: 0.8734
# Epoch 27/100
# 5243/5243 - 0s - loss: 0.2779 - accuracy: 0.8703
# Epoch 28/100
# 5243/5243 - 0s - loss: 0.2773 - accuracy: 0.8728
# Epoch 29/100
# 5243/5243 - 0s - loss: 0.2753 - accuracy: 0.8755
# Epoch 30/100
# 5243/5243 - 0s - loss: 0.2696 - accuracy: 0.8779
# Epoch 31/100
# 5243/5243 - 0s - loss: 0.2733 - accuracy: 0.8756
# Epoch 32/100
# 5243/5243 - 0s - loss: 0.2729 - accuracy: 0.8772
# Epoch 33/100
# 5243/5243 - 0s - loss: 0.2720 - accuracy: 0.8745
# Epoch 34/100
# 5243/5243 - 0s - loss: 0.2671 - accuracy: 0.8810
# Epoch 35/100
# 5243/5243 - 0s - loss: 0.2673 - accuracy: 0.8804
# Epoch 36/100
# 5243/5243 - 0s - loss: 0.2651 - accuracy: 0.8856
# Epoch 37/100
# 5243/5243 - 0s - loss: 0.2645 - accuracy: 0.8814
# Epoch 38/100
# 5243/5243 - 0s - loss: 0.2636 - accuracy: 0.8819
# Epoch 39/100
# 5243/5243 - 0s - loss: 0.2624 - accuracy: 0.8844
# Epoch 40/100
# 5243/5243 - 0s - loss: 0.2629 - accuracy: 0.8808
# Epoch 41/100
# 5243/5243 - 0s - loss: 0.2581 - accuracy: 0.8859
# Epoch 42/100
# 5243/5243 - 0s - loss: 0.2566 - accuracy: 0.8863
# Epoch 43/100
# 5243/5243 - 0s - loss: 0.2587 - accuracy: 0.8861
# Epoch 44/100
# 5243/5243 - 0s - loss: 0.2585 - accuracy: 0.8867
# Epoch 45/100
# 5243/5243 - 0s - loss: 0.2644 - accuracy: 0.8823
# Epoch 46/100
# 5243/5243 - 0s - loss: 0.2556 - accuracy: 0.8886
# Epoch 47/100
# 5243/5243 - 0s - loss: 0.2530 - accuracy: 0.8863
# Epoch 48/100
# 5243/5243 - 0s - loss: 0.2551 - accuracy: 0.8856
# Epoch 49/100
# 5243/5243 - 0s - loss: 0.2528 - accuracy: 0.8858
# Epoch 50/100
# 5243/5243 - 0s - loss: 0.2522 - accuracy: 0.8886
# Epoch 51/100
# 5243/5243 - 0s - loss: 0.2523 - accuracy: 0.8880
# Epoch 52/100
# 5243/5243 - 0s - loss: 0.2479 - accuracy: 0.8903
# Epoch 53/100
# 5243/5243 - 0s - loss: 0.2498 - accuracy: 0.8932
# Epoch 54/100
# 5243/5243 - 0s - loss: 0.2468 - accuracy: 0.8917
# Epoch 55/100
# 5243/5243 - 0s - loss: 0.2493 - accuracy: 0.8911
# Epoch 56/100
# 5243/5243 - 0s - loss: 0.2500 - accuracy: 0.8869
# Epoch 57/100
# 5243/5243 - 0s - loss: 0.2545 - accuracy: 0.8842
# Epoch 58/100
# 5243/5243 - 0s - loss: 0.2463 - accuracy: 0.8922
# Epoch 59/100
# 5243/5243 - 0s - loss: 0.2477 - accuracy: 0.8905
# Epoch 60/100
# 5243/5243 - 0s - loss: 0.2468 - accuracy: 0.8896
# Epoch 61/100
# 5243/5243 - 0s - loss: 0.2444 - accuracy: 0.8903
# Epoch 62/100
# 5243/5243 - 0s - loss: 0.2475 - accuracy: 0.8896
# Epoch 63/100
# 5243/5243 - 0s - loss: 0.2433 - accuracy: 0.8955
# Epoch 64/100
# 5243/5243 - 0s - loss: 0.2488 - accuracy: 0.8913
# Epoch 65/100
# 5243/5243 - 0s - loss: 0.2429 - accuracy: 0.8924
# Epoch 66/100
# 5243/5243 - 0s - loss: 0.2414 - accuracy: 0.8917
# Epoch 67/100
# 5243/5243 - 0s - loss: 0.2470 - accuracy: 0.8875
# Epoch 68/100
# 5243/5243 - 0s - loss: 0.2436 - accuracy: 0.8947
# Epoch 69/100
# 5243/5243 - 0s - loss: 0.2388 - accuracy: 0.8957
# Epoch 70/100
# 5243/5243 - 0s - loss: 0.2388 - accuracy: 0.8926
# Epoch 71/100
# 5243/5243 - 0s - loss: 0.2384 - accuracy: 0.8936
# Epoch 72/100
# 5243/5243 - 0s - loss: 0.2436 - accuracy: 0.8911
# Epoch 73/100
# 5243/5243 - 0s - loss: 0.2374 - accuracy: 0.8968
# Epoch 74/100
# 5243/5243 - 0s - loss: 0.2393 - accuracy: 0.8964
# Epoch 75/100
# 5243/5243 - 0s - loss: 0.2353 - accuracy: 0.8959
# Epoch 76/100
# 5243/5243 - 0s - loss: 0.2375 - accuracy: 0.8968
# Epoch 77/100
# 5243/5243 - 0s - loss: 0.2409 - accuracy: 0.8947
# Epoch 78/100
# 5243/5243 - 0s - loss: 0.2387 - accuracy: 0.8968
# Epoch 79/100
# 5243/5243 - 0s - loss: 0.2323 - accuracy: 0.9004
# Epoch 80/100
# 5243/5243 - 0s - loss: 0.2392 - accuracy: 0.8968
# Epoch 81/100
# 5243/5243 - 0s - loss: 0.2375 - accuracy: 0.8943
# Epoch 82/100
# 5243/5243 - 0s - loss: 0.2333 - accuracy: 0.8999
# Epoch 83/100
# 5243/5243 - 0s - loss: 0.2324 - accuracy: 0.8959
# Epoch 84/100
# 5243/5243 - 0s - loss: 0.2333 - accuracy: 0.8997
# Epoch 85/100
# 5243/5243 - 0s - loss: 0.2346 - accuracy: 0.8966
# Epoch 86/100
# 5243/5243 - 0s - loss: 0.2360 - accuracy: 0.8947
# Epoch 87/100
# 5243/5243 - 0s - loss: 0.2318 - accuracy: 0.9018
# Epoch 88/100
# 5243/5243 - 0s - loss: 0.2330 - accuracy: 0.8974
# Epoch 89/100
# 5243/5243 - 0s - loss: 0.2347 - accuracy: 0.8968
# Epoch 90/100
# 5243/5243 - 0s - loss: 0.2313 - accuracy: 0.9001
# Epoch 91/100
# 5243/5243 - 0s - loss: 0.2350 - accuracy: 0.8959
# Epoch 92/100
# 5243/5243 - 0s - loss: 0.2413 - accuracy: 0.8892
# Epoch 93/100
# 5243/5243 - 0s - loss: 0.2360 - accuracy: 0.8943
# Epoch 94/100
# 5243/5243 - 0s - loss: 0.2315 - accuracy: 0.9004
# Epoch 95/100
# 5243/5243 - 0s - loss: 0.2289 - accuracy: 0.9043
# Epoch 96/100
# 5243/5243 - 0s - loss: 0.2348 - accuracy: 0.8964
# Epoch 97/100
# 5243/5243 - 0s - loss: 0.2308 - accuracy: 0.8961
# Epoch 98/100
# 5243/5243 - 0s - loss: 0.2304 - accuracy: 0.8980
# Epoch 99/100
# 5243/5243 - 0s - loss: 0.2303 - accuracy: 0.8987
# Epoch 100/100
# 5243/5243 - 0s - loss: 0.2309 - accuracy: 0.9004

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1748/1 - 0s - loss: 0.3060 - accuracy: 0.8993
# Deep Neural Network - Loss: 0.2669288119134968, Accuracy: 0.8993135094642639

# %%
# make predictions and print the results
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {y_test.values[:5].tolist()}")
# Out:
# Predicted classes: ['FALSE POSITIVE' 'CANDIDATE' 'FALSE POSITIVE' 'FALSE POSITIVE'
#  'FALSE POSITIVE']
# Actual Labels: [['FALSE POSITIVE'], ['CANDIDATE'], ['FALSE POSITIVE'], ['FALSE POSITIVE'], ['FALSE POSITIVE']]

# %% [markdown]
# ###   Deep Learning model with random state 42 (V6) accuracy slightly better than random state 1 (V5).  The best accuracy is 89.93% and loss rate is 26.69%
